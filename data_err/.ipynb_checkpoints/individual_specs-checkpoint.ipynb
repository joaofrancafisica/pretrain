# %%
import glob #to read the files
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from scipy.interpolate import interp1d
import os.path 
from tabulate import tabulate #to export in table format

# %%
sn_names = "SN2001V3.dat"

# %%
y = []
z = []
zerr = []

file = open(sn_names)
lines = file.readlines()
file.close()

for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    y.append(co[0])
    z.append(co[1])
    zerr.append(co[2])
    
y = np.array(y, dtype=float)
z = np.array(z, dtype=float)
zerr = np.array(zerr, dtype=float)

# %%
yori = []
zori = []
#zerrori = []

file = open('/home/joao/Documents/pesquisa/PreTrain/data/'+'SN2012fr12.dat')
lines = file.readlines()
file.close()

for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    yori.append(co[0])
    zori.append(co[1])
    #zerrori.append(co[2])
    
yori = np.array(yori, dtype=float)
zori = np.array(zori, dtype=float)
#zerrori = np.array(zerrori, dtype=float)

# %%
# %matplotlib inline
plt.plot(y, z, 'k', lw=3, zorder=9)
plt.fill_between(y, z - zerr, z + zerr, alpha=0.5, color='k')
#plt.plot(yori, zori,'r')

# %%
z
# Out:
# array([1.15184e-16, 1.11124e-16, 1.06201e-16, 1.01637e-16, 9.86524e-17,
#        9.82905e-17, 1.01394e-16, 1.08650e-16, 1.20543e-16, 1.37184e-16,
#        1.57995e-16, 1.81438e-16, 2.05015e-16, 2.25785e-16, 4.44781e-16,
#        4.69961e-16, 4.97963e-16, 5.27040e-16, 6.32604e-16, 7.07476e-16,
#        7.83824e-16, 8.56412e-16, 9.21098e-16, 9.75518e-16, 1.01944e-15,
#        1.05520e-15, 1.08763e-15, 1.12289e-15, 1.16593e-15, 1.21795e-15,
#        1.27577e-15, 1.33294e-15, 1.38174e-15, 1.41526e-15, 1.42917e-15,
#        1.42303e-15, 1.40072e-15, 1.37011e-15, 1.34191e-15, 1.32784e-15,
#        1.33844e-15, 1.38078e-15, 1.45623e-15, 6.05940e-16, 1.67935e-15,
#        6.43147e-16, 8.75412e-15, 8.41478e-15, 8.01814e-15, 7.58415e-15,
#        7.08337e-15, 6.53735e-15, 6.01680e-15, 5.56577e-15, 5.21053e-15,
#        4.96421e-15, 4.83541e-15, 4.83299e-15, 4.96750e-15, 5.24969e-15,
#        5.68699e-15, 6.27885e-15, 7.01268e-15, 7.86151e-15, 8.78399e-15,
# ...
